# %%
# 导入模块
import matplotlib.pyplot as plt

# %%
# 第一个是x轴，第二个是y轴
plt.plot([1, 0, 9], [4, 5, 6])
# 显示图形
plt.show()

# %%
for i in range(9, 0, -1):
    print(i)
# Out:
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1
