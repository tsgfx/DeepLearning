# %%
import matplotlib.pyplot as plt
import networkx as nx

# 创建一个有向图
G = nx.DiGraph()

# 定义文法的非终结符和它们的产生式
G.add_edge('Program', 'ProgramBody')
G.add_edge('ProgramBody', 'ConstDeclaration')
G.add_edge('ProgramBody', 'VarDeclaration')
G.add_edge('ProgramBody', 'ProcedureDeclaration')
G.add_edge('ProgramBody', 'StatementSequence')
G.add_edge('ConstDeclaration', 'Constant')
G.add_edge('Constant', 'Identifier')
G.add_edge('Constant', 'Number')
G.add_edge('VarDeclaration', 'Identifier')
G.add_edge('StatementSequence', 'Statement')
G.add_edge('Statement', 'Assignment')
G.add_edge('Statement', 'Call')
G.add_edge('Statement', 'IfStatement')
G.add_edge('Statement', 'WhileStatement')
G.add_edge('Statement', 'BeginEndBlock')

# 设置图形的布局
pos = nx.spring_layout(G, seed=42)

# 绘制图形
plt.figure(figsize=(10, 8))
nx.draw(G, pos, with_labels=True, node_size=3000, node_color='skyblue', font_size=10, font_weight='bold', arrows=True)

# 显示图形
plt.title("PL/0 Language Grammar")
plt.show()
